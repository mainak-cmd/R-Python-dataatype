# %% [markdown]
# #### Keras vs Tensorflow

# %% [markdown]
# Level of abstraction: Keras is a high-level API for building and training neural networks, whereas TensorFlow is a lower-level framework that provides more flexibility and control. Keras is easier to use and more user-friendly, while TensorFlow offers more customization options.

# %% [markdown]
# Ease of use: Keras is designed to be easy to use and can be learned quickly, even by those with little experience in deep learning. TensorFlow, on the other hand, has a steeper learning curve and requires more knowledge of the underlying concepts of deep learning.

# %% [markdown]
# Flexibility: TensorFlow is more flexible than Keras, allowing developers to customize and fine-tune every aspect of their models. Keras, on the other hand, is designed to be simple and easy to use, so it doesn't offer the same level of flexibility.

# %% [markdown]
# Deployment: Keras is designed to be more portable and easier to deploy than TensorFlow. Keras models can be easily converted to other formats, such as TensorFlow or ONNX, which makes it easier to use them in different environments and on different platforms.

# %% [markdown]
# ### Model API

# %% [markdown]
# The Model API (Application Programming Interface) is a set of programming instructions and standards for building, training, and deploying machine learning models. In the context of deep learning, the Model API is typically used to build and train neural networks.

# %% [markdown]
# The Model API typically provides a set of high-level functions and classes that make it easy to define, compile, and train a neural network.

# %% [markdown]
# ### Neural Network Components

# %% [markdown]
# Layers: A layer is a building block of a neural network, and the Model API provides a set of pre-defined layers, such as convolutional layers, pooling layers, and dense layers.
#
# Models: A model is a collection of layers that are stacked together to form a neural network. The Model API provides functions for creating and compiling models, and for training and evaluating them.
#
# Optimizers: An optimizer is an algorithm that is used to update the weights of the neural network during training. The Model API provides a set of pre-defined optimizers, such as stochastic gradient descent (SGD), Adam, and RMSprop.
#
# Loss functions: A loss function is used to measure how well the neural network is performing during training. The Model API provides a set of pre-defined loss functions, such as mean squared error (MSE), binary cross-entropy, and categorical cross-entropy.
#
# Metrics: A metric is used to evaluate the performance of the neural network during training and testing. The Model API provides a set of pre-defined metrics, such as accuracy, precision, and recall.

# %% [markdown]
# ## Model class

# %% [markdown]
# In Keras, the Model class is a high-level API for defining and training neural network models. It is a subclass of the Container class, which is used to group layers together into a single model.

# %% [markdown]
# The Model class provides a simple and flexible way to define a neural network model using the functional API.

# %% [markdown]
# To define a model using the Model class, you typically do the following:
#
# Define the input layer(s) of the model using the Input function.
#
# Define the layers of the model, connecting them to the input layer(s) using the functional API.
#
# Define the output layer(s) of the model, connecting them to the last layer(s) using the functional API.
#
# Create a new instance of the Model class, passing in the input layer(s) and output layer(s) as arguments.
#
# Compile the model, specifying the loss function, optimizer, and metrics to be used during training.
#
# Train the model on a dataset using the fit method.

# %% [markdown]
# ### Data preprocessing is an important step in machine learning and it is not always necessary to use a neural network to perform data preprocessing.

# %% [markdown]
# #### Define the input layer(s)

# %% [markdown]
# In Keras, the input layer is the first layer in a neural network model. It defines the shape of the input data that will be fed into the model

# %%
from keras.layers import Input

# Define the input layer with a shape of (10,)
inputs = Input(shape=(10,))

# %% [markdown]
# This means that the input data should be a 1D array of length 10. The Input class returns a symbolic tensor that will be used as a placeholder for the actual input data when the model is compiled and trained.

# %% [markdown]
# Note that the input shape should match the shape of the input data that will be used to train the model.

# %% [markdown]
# ##### input data of any length along that dimension

# %% [markdown]
# If you set the shape of a particular dimension to None, it means that the model can accept input data of any length along that dimension.

# %%
# Define the input layer with variable length
inputs = Input(shape=(None, 1))

# %% [markdown]
# we define an input layer with shape (None, 1), which means that the input data can have any length along the first dimension, but must have a length of 1 along the second dimension (i.e., it should be a 2D array where the second dimension has length 1) (n row and 1 colloumn).

# %%
inputs = Input(shape=(None,None )) #(Row number ,colloumn number)
inputs_1 = Input(shape=(None,None,3 )) #(depth ,row ,colloumn)
inputs_2 = Input(shape=(None,3,None ))

# %% [markdown]
# #### Define the hidden layer

# %% [markdown]
# In a neural network, a hidden layer is a layer that is neither an input layer nor an output layer. Hidden layers are where most of the computation in a neural network takes place, as the neurons in these layers apply transformations to the input data in order to extract useful features.

# %% [markdown]
# ####  there are several types of hidden layers that can be used depending on the nature of the problem you are trying to solve

# %% [markdown]
# Fully connected layer: Also known as a dense layer, this is the most basic type of hidden layer in which every neuron in the layer is connected to every neuron in the previous layer.
#
#
# IMage
# Convolutional layer: This is a type of layer used in convolutional neural networks (CNNs) for image and signal processing tasks. It applies a convolution operation to the input data, which involves sliding a filter over the input and computing dot products at each position.
#
# Pooling layer: This is a type of layer often used in conjunction with convolutional layers in CNNs. It reduces the spatial dimensions of the output from the previous layer by taking the maximum or average value over a small region.
#
# spatial dimensions:Spatial dimensions refer to the three-dimensional space in which we live, move and interact. They are often described as length, width, and height, and are commonly represented by the x, y, and z axes respectively.
#
# NLP
#
# Recurrent layer: This is a type of layer used in recurrent neural networks (RNNs) for processing sequential data. It applies a recurrent transformation to the input data, which allows the network to capture temporal dependencies in the data.
#
#
# Overfitting
#
# Dropout layer: This is a regularization technique that can be applied to any type of layer in a neural network. It randomly drops out some of the activations from the previous layer during training in order to prevent overfitting.
#
#
#
# Batch normalization layer: This is a type of layer that can be used to improve the training of deep neural networks. It normalizes the output of the previous layer to have zero mean and unit variance, which helps to prevent the values from becoming too large or too small during training.
#
#
# Note that in many cases, a combination of different types of layers may be used in a neural network architecture, depending on the specific requirements of the problem.

# %% [markdown]
# #### Fully connected layer

# %% [markdown]
# Fully connected layer: Also known as a dense layer, this is the most basic type of hidden layer in which every neuron in the layer is connected to every neuron in the previous layer.

# %% [markdown]
# The weights and biases in a fully connected layer are learned during training using an optimization algorithm such as stochastic gradient descent (SGD)

# %% [markdown]
# SGD (Stochastic Gradient Descent): This is a simple optimizer that updates the parameters in the direction of the negative gradient of the loss function. It is computationally efficient and easy to implement, but can be slow to converge and can get stuck in local minima.

# %% [markdown]
# The backpropagation algorithm is used to compute the gradients of the loss function with respect to the weights and biases in the layer, which are then used to update the parameters.

# %% [markdown]
# ##### The input to a fully connected layer is a vector, and the output is another vector of a specified size.

# %% [markdown]
# The fully connected layer is typically used in the final stages of a neural network to map the output of the previous layer to the output of the network.

# %% [markdown]
# For example, if you have a binary classification problem, you might use a single neuron in the output layer with a sigmoid activation function to output a probability of class membership.

# %% [markdown]
# ### USES

# %% [markdown]
# Fully connected layers are used in various neural network architectures and are a fundamental building block in deep learning. Here are some common use cases for fully connected layers:

# %% [markdown]
# Image Classification: In image classification tasks, fully connected layers are often used as the output layer to map the learned features from convolutional layers to class scores. For example, in the popular VGG16 architecture, the fully connected layers are used at the end to produce the final output probabilities for different classes.
#
# Language Modeling: Fully connected layers are also used in natural language processing tasks such as language modeling, where the input is a sequence of words and the output is a probability distribution over the next word. In this case, the fully connected layer is used as the output layer to predict the next word based on the learned representations from the previous layers.
#
# Regression: Fully connected layers can also be used for regression tasks, where the goal is to predict a continuous output variable. For example, in a housing price prediction problem, the fully connected layer can be used to map the learned features to a single output value representing the predicted price.
#
# Transfer Learning: Fully connected layers are often used in transfer learning, where a pre-trained model is used as a starting point for a new task. In this case, the fully connected layers of the pre-trained model can be frozen while the newly added layers are trained on the new task. This can save training time and improve the performance of the model on the new task.

# %% [markdown]
# A dense layer with 32 units means that the layer has 32 neurons, also known as nodes or units. Each of these neurons is fully connected to the neurons in the previous layer (or input data, if this is the first layer), and the output of each neuron is calculated as a weighted sum of the inputs, followed by an activation function.

# %% [markdown]
# The weights and biases associated with each neuron are learned during the training process, so that the network can learn to produce appropriate output values for a given input. The number of units in a dense layer is a hyperparameter that can be tuned to optimize the performance of the network on a given task. In general, increasing the number of units in a dense layer can increase the capacity of the network to learn complex patterns in the data, but can also increase the risk of overfitting if the model becomes too complex.

# %% [markdown]
# ### Regression

# %%
import numpy as np
from tensorflow import keras
from keras.layers import Input

# generate random input data
X = np.random.rand(100,5)

# generate random output data
y = np.random.rand(100, 1)

# define the model architecture
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(5, ), activation='relu'),
    keras.layers.Dense(3),
    keras.layers.Dense(1)
])

""""keras.layers.Dense is a function in the Keras API that creates a dense layer for a neural network. 
A dense layer is a type of fully connected layer, 
where each neuron in the layer is connected to every neuron in the previous layer.

10 is the number of neurons in the dense layer.

input_shape is a parameter that specifies the shape of the input data for the layer. 
In this case, the input shape is (5,), which means that the input data has 5 features. 
Note that input_shape is only used for the first layer of the network. For subsequent layers, 
the input shape is automatically inferred from the output shape of the previous layer.

activation is a parameter that specifies the activation function for the layer.
In this case, the activation function is ReLU (rectified linear unit),
which is commonly used in neural networks to introduce non-linearity."""

# compile the model
model.compile(loss='mse', optimizer='adam')

# train the model
model.fit(X, y, epochs=1000, verbose=2)

""""epochs is a parameter that specifies the number of epochs to train the model.
An epoch is a single iteration over the entire input data. In this case, the model will be trained for 1000 epochs.

verbose is a parameter that specifies how much output to display during training.
A value of 0 means no output, a value of 1 means progress bars for each epoch,
and a value of 2 means one line of output per epoch."""


# evaluate the model
mse = model.evaluate(X, y, verbose=0)
print(f"Mean Squared Error: {mse:.4f}")
# Out:
# Epoch 1/1000
# 4/4 - 1s - loss: 0.3911 - 986ms/epoch - 246ms/step
# Epoch 2/1000
# 4/4 - 0s - loss: 0.3433 - 15ms/epoch - 4ms/step
# Epoch 3/1000
# 4/4 - 0s - loss: 0.2988 - 17ms/epoch - 4ms/step
# Epoch 4/1000
# 4/4 - 0s - loss: 0.2617 - 17ms/epoch - 4ms/step
# Epoch 5/1000
# 4/4 - 0s - loss: 0.2271 - 17ms/epoch - 4ms/step
# Epoch 6/1000
# 4/4 - 0s - loss: 0.1983 - 18ms/epoch - 5ms/step
# Epoch 7/1000
# 4/4 - 0s - loss: 0.1732 - 20ms/epoch - 5ms/step
# Epoch 8/1000
# 4/4 - 0s - loss: 0.1511 - 17ms/epoch - 4ms/step
# Epoch 9/1000
# 4/4 - 0s - loss: 0.1343 - 17ms/epoch - 4ms/step
# Epoch 10/1000
# 4/4 - 0s - loss:
# Epoch 172/1000
# 4/4 - 0s - loss: 0.0829 - 13ms/epoch - 3ms/step
# Epoch 173/1000
# 4/4 - 0s - loss: 0.0825 - 17ms/epoch - 4ms/step
# Epoch 174/1000
# 4/4 - 0s - loss: 0.0819 - 12ms/epoch - 3ms/step
# Epoch 175/1000
# 4/4 - 0s - loss: 0.0817 - 11ms/epoch - 3ms/step
# Epoch 176/1000
# 4/4 - 0s - loss: 0.0817 - 13ms/epoch - 3ms/step
# Epoch 177/1000
# 4/4 - 0s - loss: 0.0816 - 15ms/epoch - 4ms/step
# Epoch 178/1000
# 4/4 - 0s - loss: 0.0816 - 12ms/epoch - 3ms/step
# Epoch 179/1000
# 4/4 - 0s - loss: 0.0814 - 12ms/epoch - 3ms/step
# Epoch 180/1000
# 4/4 - 0s - loss: 0.0814 - 12ms/epoch - 3ms/step
# Epoch 181/1000
# 4/4 - 0s - loss: 0.0817 - 13ms/epoch - 3ms/step
# Epoch 182/1000
# 4/4 - 0s - loss: 0.0819 - 15ms/epoch - 4ms/step
# Epoch 183/1000
# 4/4 - 0s - loss: 0.0821 - 22ms/epoch - 6ms/step
# Epoch 184/1000
# 4/4 - 0s - loss: 0.0822 - 13ms/epoch - 3ms/step
# Epoch 185/1000
# 4/4 - 0s - loss: 0.0821 - 16ms/epoch - 4ms/step
# Epoch 186/1000
# 4/4 - 0s - loss: 0.0815 - 13ms/epoch - 3ms/step
# Epoch 187/1000
# 4/4 - 0s - loss: 0.0811 - 16ms/epoch - 4ms/step
# Epoch 188/1000
# 4/4 - 0s - loss: 0.0813 - 22ms/epoch - 6ms/step
# Epoch 189/1000
# 4/4 - 0s - loss: 0.0812 - 14ms/epoch - 4ms/step
# Epoch 190/1000
# 4/4 - 0s - loss: 0.0813 - 14ms/epoch - 4ms/step
# Epoch 191/1000
# 4/4 - 0s - loss: 0.0824 - 12ms/epoch - 3ms/step
# Epoch 192/1000
# 4/4 - 0s - loss: 0.0827 - 13ms/epoch - 3ms/step
# Epoch 193/1000
# 4/4 - 0s - loss: 0.0819 - 12ms/epoch - 3ms/step
# Epoch 194/1000
# 4/4 - 0s - loss: 0.0813 - 12ms/epoch - 3ms/step
# Epoch 195/1000
# 4/4 - 0s - loss: 0.0811 - 14ms/epoch - 4ms/step
# Epoch 196/1000
# 4/4 - 0s - loss: 0.0816 - 14ms/epoch - 3ms/step
# Epoch 197/1000
# 4/4 - 0s - loss: 0.0819 - 12ms/epoch - 3ms/step
# Epoch 198/1000
# 4/4 - 0s - loss: 0.0818 - 11ms/epoch - 3ms/step
# Epoch 199/1000
# 4/4 - 0s - loss: 0.0816 - 11ms/epoch - 3ms/step
# Epoch 200/1000
# 4/4 - 0s - loss: 0.0810 - 11ms/epoch - 3ms/step
# Epoch 201/1000
# 4/4 - 0s - loss: 0.0811 - 11ms/epoch - 3ms/step
# Epoch 202/1000
# 4/4 - 0s - loss: 0.0814 - 11ms/epoch - 3ms/step
# Epoch 203/1000
# 4/4 - 0s - loss: 0.0815 - 13ms/epoch - 3ms/step
# Epoch 204/1000
# 4/4 - 0s - loss: 0.0813 - 10ms/epoch - 2ms/step
# Epoch 205/1000
# 4/4 - 0s - loss: 0.0810 - 14ms/epoch - 3ms/step
# Epoch 206/1000
# 4/4 - 0s - loss: 0.0811 - 19ms/epoch - 5ms/step
# Epoch 207/1000
# 4/4 - 0s - loss: 0.0812 - 14ms/epoch - 4ms/step
# Epoch 208/1000
# 4/4 - 0s - loss: 0.0812 - 14ms/epoch - 3ms/step
# Epoch 209/1000
# 4/4 - 0s - loss: 0.0809 - 14ms/epoch - 3ms/step
# Epoch 210/1000
# 4/4 - 0s - loss: 0.0808 - 12ms/epoch - 3ms/step
# Epoch 211/1000
# 4/4 - 0s - loss: 0.0809 - 13ms/epoch - 3ms/step
# Epoch 212/1000
# 4/4 - 0s - loss: 0.0809 - 12ms/epoch - 3ms/step
# Epoch 213/1000
# 4/4 - 0s - loss: 0.0810 - 14ms/epoch - 4ms/step
# Epoch 214/1000
# 4/4 - 0s - loss: 0.0810 - 11ms/epoch - 3ms/step
# Epoch 215/1000
# 4/4 - 0s - loss: 0.0808 - 12ms/epoch - 3ms/step
# Epoch 216/1000
# 4/4 - 0s - loss: 0.0807 - 11ms/epoch - 3ms/step
# Epoch 217/1000
# 4/4 - 0s - loss: 0.0808 - 14ms/epoch - 4ms/step
# Epoch 218/1000
# 4/4 - 0s - loss: 0.0807 - 12ms/epoch - 3ms/step
# Epoch 219/1000
# 4/4 - 0s - loss: 0.0810 - 15ms/epoch - 4ms/step
# Epoch 220/1000
# 4/4 - 0s - loss: 0.0811 - 11ms/epoch - 3ms/step
# Epoch 221/1000
# 4/4 - 0s - loss: 0.0811 - 14ms/epoch - 3ms/step
# Epoch 222/1000
# 4/4 - 0s - loss: 0.0810 - 13ms/epoch - 3ms/step
# Epoch 223/1000
# 4/4 - 0s - loss: 0.0809 - 12ms/epoch - 3ms/step
# Epoch 224/1000
# 4/4 - 0s - loss: 0.0807 - 12ms/epoch - 3ms/step
# Epoch 225/1000
# 4/4 - 0s - loss: 0.0806 - 12ms/epoch - 3ms/step
# Epoch 226/1000
# 4/4 - 0s - loss: 0.0805 - 13ms/epoch - 3ms/step
# Epoch 227/1000
# 4/4 - 0s - loss: 0.0805 - 12ms/epoch - 3ms/step
# Epoch 228/1000
# 4/4 - 0s - loss: 0.0806 - 14ms/epoch - 4ms/step
# Epoch 229/1000
# 4/4 - 0s - loss: 0.0805 - 14ms/epoch - 4ms/step
# Epoch 230/1000
# 4/4 - 0s - loss: 0.0805 - 12ms/epoch - 3ms/step
# Epoch 231/1000
# 4/4 - 0s - loss: 0.0805 - 15ms/epoch - 4ms/step
# Epoch 232/1000
# 4/4 - 0s - loss: 0.0805 - 13ms/epoch - 3ms/step
# Epoch 233/1000
# 4/4 - 0s - loss: 0.0805 - 13ms/epoch - 3ms/step
# Epoch 234/1000
# 4/4 - 0s - loss: 0.0803 - 13ms/epoch - 3ms/step
# Epoch 235/1000
# 4/4 - 0s - loss: 0.0804 - 13ms/epoch - 3ms/step
# Epoch 236/1000
# 4/4 - 0s - loss: 0.0808 - 13ms/epoch - 3ms/step
# Epoch 237/1000
# 4/4 - 0s - loss: 0.0818 - 13ms/epoch - 3ms/step
# Epoch 238/1000
# 4/4 - 0s - loss: 0.0825 - 13ms/epoch - 3ms/step
# Epoch 239/1000
# 4/4 - 0s - loss: 0.0825 - 12ms/epoch - 3ms/step
# Epoch 240/1000
# 4/4 - 0s - loss: 0.0825 - 12ms/epoch - 3ms/step
# Epoch 241/1000
# 4/4 - 0s - loss: 0.0823 - 13ms/epoch - 3ms/step
# Epoch 242/1000
# 4/4 - 0s - loss: 0.0817 - 11ms/epoch - 3ms/step
# Epoch 243/1000
# 4/4 - 0s - loss: 0.0809 - 14ms/epoch - 3ms/step
# Epoch 244/1000
# 4/4 - 0s - loss: 0.0807 - 14ms/epoch - 3ms/step
# Epoch 245/1000
# 4/4 - 0s - loss: 0.0806 - 12ms/epoch - 3ms/step
# Epoch 246/1000
# 4/4 - 0s - loss: 0.0805 - 12ms/epoch - 3ms/step
# Epoch 247/1000
# 4/4 - 0s - loss: 0.0804 - 11ms/epoch - 3ms/step
# Epoch 248/1000
# 4/4 - 0s - loss: 0.0805 - 12ms/epoch - 3ms/step
# Epoch 249/1000
# 4/4 - 0s - loss: 0.0803 - 13ms/epoch - 3ms/step
# Epoch 250/1000
# 4/4 - 0s - loss: 0.0804 - 13ms/epoch - 3ms/step
# Epoch 251/1000
# 4/4 - 0s - loss: 0.0802 - 14ms/epoch - 3ms/step
# Epoch 252/1000
# 4/4 - 0s - loss: 0.0804 - 13ms/epoch - 3ms/step
# Epoch 253/1000
# 4/4 - 0s - loss: 0.0802 - 13ms/epoch - 3ms/step
# Epoch 254/1000
# 4/4 - 0s - loss: 0.0804 - 11ms/epoch - 3ms/step
# Epoch 255/1000
# 4/4 - 0s - loss: 0.0807 - 15ms/epoch - 4ms/step
# Epoch 256/1000
# 4/4 - 0s - loss: 0.0807 - 15ms/epoch - 4ms/step
# Epoch 257/1000
# 4/4 - 0s - loss: 0.0804 - 14ms/epoch - 4ms/step
# Epoch 258/1000
# 4/4 - 0s - loss: 0.0803 - 14ms/epoch - 3ms/step
# Epoch 259/1000
# 4/4 - 0s - loss: 0.0803 - 15ms/epoch - 4ms/step
# Epoch 260/1000
# 4/4 - 0s - loss: 0.0802 - 13ms/epoch - 3ms/step
# Epoch 261/1000
# 4/4 - 0s - loss: 0.0803 - 15ms/epoch - 4ms/step
# Epoch 262/1000
# 4/4 - 0s - loss: 0.0807 - 13ms/epoch - 3ms/step
# Epoch 263/1000
# 4/4 - 0s - loss: 0.0803 - 11ms/epoch - 3ms/step
# Epoch 264/1000
# 4/4 - 0s - loss: 0.0802 - 13ms/epoch - 3ms/step
# Epoch 265/1000
# 4/4 - 0s - loss: 0.0801 - 15ms/epoch - 4ms/step
# Epoch 266/1000
# 4/4 - 0s - loss: 0.0801 - 14ms/epoch - 4ms/step
# Epoch 267/1000
# 4/4 - 0s - loss: 0.0804 - 17ms/epoch - 4ms/step
# Epoch 268/1000
# 4/4 - 0s - loss: 0.0810 - 11ms/epoch - 3ms/step
# Epoch 269/1000
# 4/4 - 0s - loss: 0.0811 - 12ms/epoch - 3ms/step
# Epoch 270/1000
# 4/4 - 0s - loss: 0.0804 - 12ms/epoch - 3ms/step
# Epoch 271/1000
# 4/4 - 0s - loss: 0.0801 - 13ms/epoch - 3ms/step
# Epoch 272/1000
# 4/4 - 0s - loss: 0.0801 - 12ms/epoch - 3ms/step
# Epoch 273/1000
# 4/4 - 0s - loss: 0.0805 - 15ms/epoch - 4ms/step
# Epoch 274/1000
# 4/4 - 0s - loss: 0.0804 - 15ms/epoch - 4ms/step
# Epoch 275/1000
# 4/4 - 0s - loss: 0.0802 - 14ms/epoch - 3ms/step
# Epoch 276/1000
# 4/4 - 0s - loss: 0.0803 - 13ms/epoch - 3ms/step
# Epoch 277/1000
# 4/4 - 0s - loss: 0.0800 - 15ms/epoch - 4ms/step
# Epoch 278/1000
# 4/4 - 0s - loss: 0.0801 - 14ms/epoch - 4ms/step
# Epoch 279/1000
# 4/4 - 0s - loss: 0.0799 - 20ms/epoch - 5ms/step
# Epoch 280/1000
# 4/4 - 0s - loss: 0.0800 - 18ms/epoch - 5ms/step
# Epoch 281/1000
# 4/4 - 0s - loss: 0.0802 - 17ms/epoch - 4ms/step
# Epoch 282/1000
# 4/4 - 0s - loss: 0.0806 - 13ms/epoch - 3ms/step
# Epoch 283/1000
# 4/4 - 0s - loss: 0.0807 - 15ms/epoch - 4ms/step
# Epoch 284/1000
# 4/4 - 0s - loss: 0.0807 - 14ms/epoch - 4ms/step
# Epoch 285/1000
# 4/4 - 0s - loss: 0.0804 - 14ms/epoch - 4ms/step
# Epoch 286/1000
# 4/4 - 0s - loss: 0.0803 - 16ms/epoch - 4ms/step
# Epoch 287/1000
# 4/4 - 0s - loss: 0.0802 - 11ms/epoch - 3ms/step
# Epoch 288/1000
# 4/4 - 0s - loss: 0.0801 - 11ms/epoch - 3ms/step
# Epoch 289/1000
# 4/4 - 0s - loss: 0.0802 - 12ms/epoch - 3ms/step
# Epoch 290/1000
# 4/4 - 0s - loss: 0.0802 - 18ms/epoch - 4ms/step
# Epoch 291/1000
# 4/4 - 0s - loss: 0.0804 - 12ms/epoch - 3ms/step
# Epoch 292/1000
# 4/4 - 0s - loss: 0.0805 - 13ms/epoch - 3ms/step
# Epoch 293/1000
# 4/4 - 0s - loss: 0.0806 - 14ms/epoch - 3ms/step
# Epoch 294/1000
# 4/4 - 0s - loss: 0.0808 - 12ms/epoch - 3ms/step
# Epoch 295/1000
# 4/4 - 0s - loss: 0.0805 - 13ms/epoch - 3ms/step
# Epoch 296/1000
# 4/4 - 0s - loss: 0.0801 - 16ms/epoch - 4ms/step
# Epoch 297/1000
# 4/4 - 0s - loss: 0.0801 - 16ms/epoch - 4ms/step
# Epoch 298/1000
# 4/4 - 0s - loss: 0.0801 - 14ms/epoch - 4ms/step
# Epoch 398/1000
# 4/4 - 0s - loss: 0.0789 - 11ms/epoch - 3ms/step
# Epoch 399/1000
# 4/4 - 0s - loss: 0.0789 - 10ms/epoch - 2ms/step
# Epoch 400/1000
# 4/4 - 0s - loss: 0.0789 - 12ms/epoch - 3ms/step
# Epoch 401/1000
# 4/4 - 0s - loss: 0.0793 - 12ms/epoch - 3ms/step
# Epoch 402/1000
# 4/4 - 0s - loss: 0.0793 - 12ms/epoch - 3ms/step
# Epoch 403/1000
# 4/4 - 0s - loss: 0.0793 - 13ms/epoch - 3ms/step
# Epoch 404/1000
# 4/4 - 0s - loss: 0.0791 - 12ms/epoch - 3ms/step
# Epoch 405/1000
# 4/4 - 0s - loss: 0.0790 - 10ms/epoch - 3ms/step
# Epoch 406/1000
# 4/4 - 0s - loss: 0.0788 - 10ms/epoch - 3ms/step
# Epoch 407/1000
# 4/4 - 0s - loss: 0.0787 - 15ms/epoch - 4ms/step
# Epoch 408/1000
# 4/4 - 0s - loss: 0.0788 - 17ms/epoch - 4ms/step
# Epoch 409/1000
# 4/4 - 0s - loss: 0.0788 - 13ms/epoch - 3ms/step
# Epoch 410/1000
# 4/4 - 0s - loss: 0.0789 - 13ms/epoch - 3ms/step
# Epoch 411/1000
# 4/4 - 0s - loss: 0.0789 - 12ms/epoch - 3ms/step
# Epoch 412/1000
# 4/4 - 0s - loss: 0.0789 - 12ms/epoch - 3ms/step
# Epoch 413/1000
# 4/4 - 0s - loss: 0.0793 - 12ms/epoch - 3ms/step
# Epoch 414/1000
# 4/4 - 0s - loss: 0.0799 - 10ms/epoch - 3ms/step
# Epoch 415/1000
# 4/4 - 0s - loss: 0.0801 - 9ms/epoch - 2ms/step
# Epoch 416/1000
# 4/4 - 0s - loss: 0.0796 - 11ms/epoch - 3ms/step
# Epoch 417/1000
# 4/4 - 0s - loss: 0.0792 - 12ms/epoch - 3ms/step
# Epoch 418/1000
# 4/4 - 0s - loss: 0.0791 - 13ms/epoch - 3ms/step
# Epoch 419/1000
# 4/4 - 0s - loss: 0.0791 - 13ms/epoch - 3ms/step
# Epoch 420/1000
# 4/4 - 0s - loss: 0.0796 - 12ms/epoch - 3ms/step
# Epoch 421/1000
# 4/4 - 0s - loss: 0.0801 - 11ms/epoch - 3ms/step
# Epoch 422/1000
# 4/4 - 0s - loss: 0.0804 - 11ms/epoch - 3ms/step
# Epoch 423/1000
# 4/4 - 0s - loss: 0.0801 - 11ms/epoch - 3ms/step
# Epoch 424/1000
# 4/4 - 0s - loss: 0.0791 - 11ms/epoch - 3ms/step
# Epoch 425/1000
# 4/4 - 0s - loss: 0.0787 - 12ms/epoch - 3ms/step
# Epoch 426/1000
# 4/4 - 0s - loss: 0.0788 - 12ms/epoch - 3ms/step
# Epoch 427/1000
# 4/4 - 0s - loss: 0.0792 - 12ms/epoch - 3ms/step
# Epoch
# 4/4 - 0s - loss: 0.0783 - 10ms/epoch - 2ms/step
# Epoch 464/1000
# 4/4 - 0s - loss: 0.0779 - 14ms/epoch - 4ms/step
# Epoch 465/1000
# 4/4 - 0s - loss: 0.0788 - 13ms/epoch - 3ms/step
# Epoch 466/1000
# 4/4 - 0s - loss: 0.0795 - 11ms/epoch - 3ms/step
# Epoch 467/1000
# 4/4 - 0s - loss: 0.0801 - 10ms/epoch - 2ms/step
# Epoch 468/1000
# 4/4 - 0s - loss: 0.0797 - 12ms/epoch - 3ms/step
# Epoch 469/1000
# 4/4 - 0s - loss: 0.0783 - 12ms/epoch - 3ms/step
# Epoch 470/1000
# 4/4 - 0s - loss: 0.0779 - 13ms/epoch - 3ms/step
# Epoch 471/1000
# 4/4 - 0s - loss: 0.0784 - 13ms/epoch - 3ms/step
# Epoch 472/1000
# 4/4 - 0s - loss: 0.0788 - 18ms/epoch - 5ms/step
# Epoch 473/1000
# 4/4 - 0s - loss: 0.0792 - 13ms/epoch - 3ms/step
# Epoch 474/1000
# 4/4 - 0s - loss: 0.0792 - 43ms/epoch - 11ms/step
# Epoch 475/1000
# 4/4 - 0s - loss: 0.0793 - 18ms/epoch - 4ms/step
# Epoch 476/1000
# 4/4 - 0s - loss: 0.0791 - 17ms/epoch - 4ms/step
# Epoch 477/1000
# 4/4 - 0s - loss: 0.0784 - 17ms/epoch - 4ms/step
# Epoch 478/1000
# 4/4 - 0s - loss: 0.0780 - 20ms/epoch - 5ms/step
# Epoch 479/1000
# 4/4 - 0s - loss: 0.0779 - 15ms/epoch - 4ms/step
# Epoch 480/1000
# 4/4 - 0s - loss: 0.0790 - 13ms/epoch - 3ms/step
# Epoch 481/1000
# 4/4 - 0s - loss: 0.0799 - 14ms/epoch - 3ms/step
# Epoch 482/1000
# 4/4 - 0s - loss: 0.0792 - 15ms/epoch - 4ms/step
# Epoch 483/1000
# 4/4 - 0s - loss: 0.0788 - 14ms/epoch - 3ms/step
# Epoch 484/1000
# 4/4 - 0s - loss: 0.0778 - 16ms/epoch - 4ms/step
# Epoch 485/1000
# 4/4 - 0s - loss: 0.0781 - 18ms/epoch - 5ms/step
# Epoch 486/1000
# 4/4 - 0s - loss: 0.0784 - 15ms/epoch - 4ms/step
# Epoch 487/1000
# 4/4 - 0s - loss: 0.0783 - 12ms/epoch - 3ms/step
# Epoch 488/1000
# 4/4 - 0s - loss: 0.0783 - 14ms/epoch - 3ms/step
# Epoch 489/1000
# 4/4 - 0s - loss: 0.0779 - 14ms/epoch - 4ms/step
# Epoch 490/1000
# 4/4 - 0s - loss: 0.0780 - 14ms/epoch - 4ms/step
# Epoch 491/1000
# 4/4 - 0s - loss: 0.0779 - 14ms/epoch - 4ms/step
# Epoch 492/1000
# 4/4 - 0s - loss: 0.0781 - 13ms/epoch - 3ms/step
# Epoch 493/1000
# 4/4 - 0s - loss: 0.0786 - 13ms/epoch - 3ms/step
# Epoch 494/1000
# 4/4 - 0s - loss: 0.0782 - 12ms/epoch - 3ms/step
# Epoch 495/1000
# 4/4 - 0s - loss: 0.0780 - 12ms/epoch - 3ms/step
# Epoch 496/1000
# 4/4 - 0s - loss: 0.0777 - 12ms/epoch - 3ms/step
# Epoch 497/1000
# 4/4 - 0s - loss: 0.0777 - 17ms/epoch - 4ms/step
# Epoch 498/1000
# 4/4 - 0s - loss: 0.0777 - 14ms/epoch - 3ms/step
# Epoch 499/1000
# 4/4 - 0s - loss: 0.0776 - 13ms/epoch - 3ms/step
# Epoch 500/1000
# 4/4 - 0s - loss: 0.0776 - 12ms/epoch - 3ms/step
# Epoch 501/1000
# 4/4 - 0s - loss: 0.0776 - 13ms/epoch - 3ms/step
# Epoch 502/1000
# 4/4 - 0s - loss: 0.0777 - 11ms/epoch - 3ms/step
# Epoch 503/1000
# 4/4 - 0s - loss: 0.0777 - 12ms/epoch - 3ms/step
# Epoch 504/1000
# 4/4 - 0s - loss: 0.0777 - 12ms/epoch - 3ms/step
# Epoch 505/1000
# 4/4 - 0s - loss: 0.0778 - 13ms/epoch - 3ms/step
# Epoch 506/1000
# 4/4 - 0s - loss: 0.0783 - 13ms/epoch - 3ms/step
# Epoch 507/1000
# 4/4 - 0s - loss: 0.0786 - 14ms/epoch - 4ms/step
# Epoch 508/1000
# 4/4 - 0s - loss: 0.0779 - 11ms/epoch - 3ms/step
# Epoch 509/1000
# 4/4 - 0s - loss: 0.0775 - 11ms/epoch - 3ms/step
# Epoch 510/1000
# 4/4 - 0s - loss: 0.0780 - 21ms/epoch - 5ms/step
# Epoch 511/1000
# 4/4 - 0s - loss: 0.0779 - 14ms/epoch - 3ms/step
# Epoch 512/1000
# 4/4 - 0s - loss: 0.0776 - 13ms/epoch - 3ms/step
# Epoch 513/1000
# 4/4 - 0s - loss: 0.0776 - 13ms/epoch - 3ms/step
# Epoch 514/1000
# 4/4 - 0s - loss: 0.0776 - 12ms/epoch - 3ms/step
# Epoch 515/1000
# 4/4 - 0s - loss: 0.0783 - 16ms/epoch - 4ms/step
# Epoch 516/1000
# 4/4 - 0s - loss: 0.0784 - 14ms/epoch - 4ms/step
# Epoch 517/1000
# 4/4 - 0s - loss: 0.0782 - 12ms/epoch - 3ms/step
# Epoch 518/1000
# 4/4 - 0s - loss: 0.0777 - 13ms/epoch - 3ms/step
# Epoch 519/1000
# 4/4 - 0s - loss: 0.0776 - 13ms/epoch - 3ms/step
# Epoch 520/1000
# 4/4 - 0s - loss: 0.0779 - 11ms/epoch - 3ms/step
# Epoch 521/1000
# 4/4 - 0s - loss: 0.0779 - 16ms/epoch - 4ms/step
# Epoch 522/1000
# 4/4 - 0s - loss: 0.0782 - 12ms/epoch - 3ms/step
# Epoch 523/1000
# 4/4 - 0s - loss: 0.0783 - 15ms/epoch - 4ms/step
# Epoch 524/1000
# 4/4 - 0s - loss: 0.0780 - 12ms/epoch - 3ms/step
# Epoch 525/1000
# 4/4 - 0s - loss: 0.0774 - 15ms/epoch - 4ms/step
# Epoch 526/1000
# 4/4 - 0s - loss: 0.0773 - 14ms/epoch - 3ms/step
# Epoch 527/1000
# 4/4 - 0s - loss: 0.0773 - 19ms/epoch - 5ms/step
# Epoch 528/1000
# 4/4 - 0s - loss: 0.0775 - 14ms/epoch - 3ms/step
# Epoch 529/1000
# 4/4 - 0s - loss: 0.0773 - 16ms/epoch - 4ms/step
# Epoch 530/1000
# 4/4 - 0s - loss: 0.0773 - 11ms/epoch - 3ms/step
# Epoch 531/1000
# 4/4 - 0s - loss: 0.0773 - 14ms/epoch - 3ms/step
# Epoch 532/1000
# 4/4 - 0s - loss: 0.0773 - 13ms/epoch - 3ms/step
# Epoch 533/1000
# 4/4 - 0s - loss: 0.0775 - 12ms/epoch - 3ms/step
# Epoch 534/1000
# 4/4 - 0s - loss: 0.0774 - 13ms/epoch - 3ms/step
# Epoch 535/1000
# 4/4 - 0s - loss: 0.0775 - 14ms/epoch - 3ms/step
# Epoch 536/1000
# 4/4 - 0s - loss: 0.0772 - 15ms/epoch - 4ms/step
# Epoch 537/1000
# 4/4 - 0s - loss: 0.0775 - 13ms/epoch - 3ms/step
# Epoch 538/1000
# 4/4 - 0s - loss: 0.0772 - 13ms/epoch - 3ms/step
# Epoch 539/1000
# 4/4 - 0s - loss: 0.0772 - 12ms/epoch - 3ms/step
# Epoch 540/1000
# 4/4 - 0s - loss: 0.0773 - 12ms/epoch - 3ms/step
# Epoch 541/1000
# 4/4 - 0s - loss: 0.0772 - 13ms/epoch - 3ms/step
# Epoch 542/1000
# 4/4 - 0s - loss: 0.0770 - 15ms/epoch - 4ms/step
# Epoch 543/1000
# 4/4 - 0s - loss: 0.0771 - 18ms/epoch - 4ms/step
# Epoch 544/1000
# 4/4 - 0s - loss: 0.0772 - 17ms/epoch - 4ms/step
# Epoch 545/1000
# 4/4 - 0s - loss: 0.0776 - 17ms/epoch - 4ms/step
# Epoch 546/1000
# 4/4 - 0s - loss: 0.0774 - 16ms/epoch - 4ms/step
# Epoch 547/1000
# 4/4 - 0s - loss: 0.0770 - 17ms/epoch - 4ms/step
# Epoch 548/1000
# 4/4 - 0s - loss: 0.0771 - 17ms/epoch - 4ms/step
# Epoch 549/1000
# 4/4 - 0s - loss: 0.0770 - 17ms/epoch - 4ms/step
# Epoch 550/1000
# 4/4 - 0s - loss: 0.0768 - 16ms/epoch - 4ms/step
# Epoch 551/1000
# 4/4 - 0s - loss: 0.0775 - 17ms/epoch - 4ms/step
# Epoch 552/1000
# 4/4 - 0s - loss: 0.0786 - 17ms/epoch - 4ms/step
# Epoch 553/1000
# 4/4 - 0s - loss: 0.0797 - 20ms/epoch - 5ms/step
# Epoch 554/1000
# 4/4 - 0s - loss: 0.0791 - 15ms/epoch - 4ms/step
# Epoch 555/1000
# 4/4 - 0s - loss: 0.0774 - 17ms/epoch - 4ms/step
# Epoch 556/1000
# 4/4 - 0s - loss: 0.0775 - 14ms/epoch - 3ms/step
# Epoch 557/1000
# 4/4 - 0s - loss: 0.0789 - 15ms/epoch - 4ms/step
# Epoch 558/1000
# 4/4 - 0s - loss: 0.0788 - 14ms/epoch - 4ms/step
# Epoch 559/1000
# 4/4 - 0s - loss: 0.0773 - 13ms/epoch - 3ms/step
# Epoch 560/1000
# 4/4 - 0s - loss: 0.0768 - 14ms/epoch - 4ms/step
# Epoch 561/1000
# 4/4 - 0s - loss: 0.0773 - 14ms/epoch - 4ms/step
# Epoch 562/1000
# 4/4 - 0s - loss: 0.0777 - 14ms/epoch - 4ms/step
# Epoch 563/1000
# 4/4 - 0s - loss: 0.0778 - 15ms/epoch - 4ms/step
# Epoch 564/1000
# 4/4 - 0s - loss: 0.0771 - 15ms/epoch - 4ms/step
# Epoch 565/1000
# 4/4 - 0s - loss: 0.0775 - 15ms/epoch - 4ms/step
# Epoch 566/1000
# 4/4 - 0s - loss: 0.0769 - 14ms/epoch - 4ms/step
# Epoch 567/1000
# 4/4 - 0s - loss: 0.0770 - 13ms/epoch - 3ms/step
# Epoch 568/1000
# 4/4 - 0s - loss: 0.0771 - 12ms/epoch - 3ms/step
# Epoch 569/1000
# 4/4 - 0s - loss: 0.0769 - 13ms/epoch - 3ms/step
# Epoch 570/1000
# 4/4 - 0s - loss: 0.0767 - 13ms/epoch - 3ms/step
# Epoch 571/1000
# 4/4 - 0s - loss: 0.0770 - 15ms/epoch - 4ms/step
# Epoch 572/1000
# 4/4 - 0s - loss: 0.0770 - 18ms/epoch - 4ms/step
# Epoch 573/1000
# 4/4 - 0s - loss: 0.0771 - 12ms/epoch - 3ms/step
# Epoch 574/1000
# 4/4 - 0s - loss: 0.0770 - 14ms/epoch - 3ms/step
# Epoch 575/1000
# 4/4 - 0s - loss: 0.0770 - 11ms/epoch - 3ms/step
# Epoch 576/1000
# 4/4 - 0s - loss: 0.0767 - 11ms/epoch - 3ms/step
# Epoch 577/1000
# 4/4 - 0s - loss: 0.0770 - 13ms/epoch - 3ms/step
# Epoch 578/1000
# 4/4 - 0s - loss: 0.0769 - 12ms/epoch - 3ms/step
# Epoch 579/1000
# 4/4 - 0s - loss: 0.0768 - 12ms/epoch - 3ms/step
# Epoch 580/1000
# 4/4 - 0s - loss: 0.0769 - 14ms/epoch - 4ms/step
# Epoch 581/1000
# 4/4 - 0s - loss: 0.0767 - 13ms/epoch - 3ms/step
# Epoch 582/1000
# 4/4 - 0s - loss: 0.0769 - 13ms/epoch - 3ms/step
# Epoch 583/1000
# 4/4 - 0s - loss: 0.0768 - 16ms/epoch - 4ms/step
# Epoch 584/1000
# 4/4 - 0s - loss: 0.0769 - 14ms/epoch - 4ms/step
# Epoch 585/1000
# 4/4 - 0s - loss: 0.0768 - 13ms/epoch - 3ms/step
# Epoch 586/1000
# 4/4 - 0s - loss: 0.0767 - 16ms/epoch - 4ms/step
# Epoch 587/1000
# 4/4 - 0s - loss: 0.0767 - 15ms/epoch - 4ms/step
# Epoch 588/1000
# 4/4 - 0s - loss: 0.0767 - 12ms/epoch - 3ms/step
# Epoch 589/1000
# 4/4 - 0s - loss: 0.0768 - 11ms/epoch - 3ms/step
# Epoch 590/1000
# 4/4 - 0s - loss: 0.0763 - 12ms/epoch - 3ms/step
# Epoch 591/1000
# 4/4 - 0s - loss: 0.0764 - 11ms/epoch - 3ms/step
# Epoch 592/1000
1000
# 4/4 - 0s - loss: 0.0772 - 13ms/epoch - 3ms/step
# Epoch 623/1000
# 4/4 - 0s - loss: 0.0777 - 12ms/epoch - 3ms/step
# Epoch 624/1000
# 4/4 - 0s - loss: 0.0772 - 13ms/epoch - 3ms/step
# Epoch 625/1000
# 4/4 - 0s - loss: 0.0764 - 15ms/epoch - 4ms/step
# Epoch 626/1000
# 4/4 - 0s - loss: 0.0762 - 14ms/epoch - 4ms/step
# Epoch 627/1000
# 4/4 - 0s - loss: 0.0761 - 12ms/epoch - 3ms/step
# Epoch 628/1000
# 4/4 - 0s - loss: 0.0761 - 12ms/epoch - 3ms/step
# Epoch 629/1000
# 4/4 - 0s - loss: 0.0762 - 18ms/epoch - 5ms/step
# Epoch 630/1000
# 4/4 - 0s - loss: 0.0764 - 15ms/epoch - 4ms/step
# Epoch 631/1000
# 4/4 - 0s - loss: 0.0766 - 13ms/epoch - 3ms/step
# Epoch 632/1000
# 4/4 - 0s - loss: 0.0767 - 14ms/epoch - 4ms/step
# Epoch 633/1000
# 4/4 - 0s - loss: 0.0762 - 13ms/epoch - 3ms/step
# Epoch 634/1000
# 4/4 - 0s - loss: 0.0760 - 13ms/epoch - 3ms/step
# Epoch 635/1000
# 4/4 - 0s - loss: 0.0759 - 14ms/epoch - 3ms/step
# Epoch 636/1000
# 4/4 - 0s - loss: 0.0760 - 12ms/epoch - 3ms/step
# Epoch 637/1000
# 4/4 - 0s - loss: 0.0759 - 13ms/epoch - 3ms/step
# Epoch 638/1000
# 4/4 - 0s - loss: 0.0759 - 13ms/epoch - 3ms/step
# Epoch 639/1000
# 4/4 - 0s - loss: 0.0759 - 13ms/epoch - 3ms/step
# Epoch 640/1000
# 4/4 - 0s - loss: 0.0762 - 13ms/epoch - 3ms/step
# Epoch 641/1000
# 4/4 - 0s - loss: 0.0763 - 13ms/epoch - 3ms/step
# Epoch 642/1000
# 4/4 - 0s - loss: 0.0756 - 14ms/epoch - 3ms/step
# Epoch 643/1000
# 4/4 - 0s - loss: 0.0759 - 15ms/epoch - 4ms/step
# Epoch 644/1000
# 4/4 - 0s - loss: 0.0760 - 16ms/epoch - 4ms/step
# Epoch 645/1000
# 4/4 - 0s - loss: 0.0760 - 17ms/epoch - 4ms/step
# Epoch 646/1000
# 4/4 - 0s - loss: 0.0760 - 15ms/epoch - 4ms/step
# Epoch 647/1000
# 4/4 - 0s - loss: 0.0756 - 13ms/epoch - 3ms/step
# Epoch 648/1000
# 4/4 - 0s - loss: 0.0765 - 18ms/epoch - 4ms/step
# Epoch 649/1000
# 4/4 - 0s - loss: 0.0768 - 23ms/epoch - 6ms/step
# Epoch 650/1000
# 4/4 - 0s - loss: 0.0771 - 22ms/epoch - 5ms/step
# Epoch 651/1000
# 4/4 - 0s - loss: 0.0771 - 17ms/epoch - 4ms/step
# Epoch 652/1000
# 4/4 - 0s - loss: 0.0771 - 20ms/epoch - 5ms/step
# Epoch 653/1000
# 4/4 - 0s - loss: 0.0771 - 20ms/epoch - 5ms/step
# Epoch 654/1000
# 4/4 - 0s - loss: 0.0766 - 17ms/epoch - 4ms/step
# Epoch 655/1000
# 4/4 - 0s - loss: 0.0759 - 15ms/epoch - 4ms/step
# Epoch 656/1000
# 4/4 - 0s - loss: 0.0755 - 17ms/epoch - 4ms/step
# Epoch 657/1000
# 4/4 - 0s - loss: 0.0756 - 15ms/epoch - 4ms/step
# Epoch 658/1000
# 4/4 - 0s - loss: 0.0759 - 19ms/epoch - 5ms/step
# Epoch 659/1000
# 4/4 - 0s - loss: 0.0762 - 17ms/epoch - 4ms/step
# Epoch 660/1000
# 4/4 - 0s - loss: 0.0762 - 17ms/epoch - 4ms/step
# Epoch 661/1000
# 4/4 - 0s - loss: 0.0760 - 17ms/epoch - 4ms/step
# Epoch 662/1000
# 4/4 - 0s - loss: 0.0758 - 15ms/epoch - 4ms/step
# Epoch 663/1000
# 4/4 - 0s - loss: 0.0760 - 16ms/epoch - 4ms/step
# Epoch 664/1000
# 4/4 - 0s - loss: 0.0759 - 24ms/epoch - 6ms/step
# Epoch 665/1000
# 4/4 - 0s - loss: 0.0757 - 13ms/epoch - 3ms/step
# Epoch 666/1000
# 4/4 - 0s - loss: 0.0754 - 12ms/epoch - 3ms/step
# Epoch 667/1000
# 4/4 - 0s - loss: 0.0754 - 12ms/epoch - 3ms/step
# Epoch 668/1000
# 4/4 - 0s - loss: 0.0754 - 11ms/epoch - 3ms/step
# Epoch 669/1000
# 4/4 - 0s - loss: 0.0753 - 12ms/epoch - 3ms/step
# Epoch 670/1000
# 4/4 - 0s - loss: 0.0753 - 11ms/epoch - 3ms/step
# Epoch 671/1000
# 4/4 - 0s - loss: 0.0752 - 12ms/epoch - 3ms/step
# Epoch 672/1000
# 4/4 - 0s - loss: 0.0758 - 12ms/epoch - 3ms/step
# Epoch 673/1000
# 4/4 - 0s - loss: 0.0763 - 15ms/epoch - 4ms/step
# Epoch 674/1000
# 4/4 - 0s - loss: 0.0759 - 16ms/epoch - 4ms/step
# Epoch 675/1000
# 4/4 - 0s - loss: 0.0755 - 13ms/epoch - 3ms/step
# Epoch 676/1000
# 4/4 - 0s - loss: 0.0751 - 18ms/epoch - 4ms/step
# Epoch 677/1000
# 4/4 - 0s - loss: 0.0752 - 16ms/epoch - 4ms/step
# Epoch 678/1000
# 4/4 - 0s - loss: 0.0752 - 18ms/epoch - 5ms/step
# Epoch 679/1000
# 4/4 - 0s - loss: 0.0752 - 12ms/epoch - 3ms/step
# Epoch 680/1000
# 4/4 - 0s - loss: 0.0752 - 16ms/epoch - 4ms/step
# Epoch 681/1000
# 4/4 - 0s - loss: 0.0751 - 12ms/epoch - 3ms/step
# Epoch 682/1000
# 4/4 - 0s - loss: 0.0752 - 11ms/epoch - 3ms/step
# Epoch 683/1000
# 4/4 - 0s - loss: 0.0752 - 15ms/epoch - 4ms/step
# Epoch 684/1000
# 4/4 - 0s - loss: 0.0751 - 11ms/epoch - 3ms/step
# Epoch 685/1000
# 4/4 - 0s - loss: 0.0750 - 12ms/epoch - 3ms/step
# Epoch 686/1000
# 4/4 - 0s - loss: 0.0759 - 14ms/epoch - 3ms/step
# Epoch 687/1000
# 4/4 - 0s - loss: 0.0758 - 25ms/epoch - 6ms/step
# Epoch 688/1000
# 4/4 - 0s - loss: 0.0755 - 19ms/epoch - 5ms/step
# Epoch 689/1000
# 4/4 - 0s - loss: 0.0752 - 19ms/epoch - 5ms/step
# Epoch 690/1000
# 4/4 - 0s - loss: 0.0750 - 16ms/epoch - 4ms/step
# Epoch 691/1000
# 4/4 - 0s - loss: 0.0749 - 22ms/epoch - 5ms/step
# Epoch 692/1000
# 4/4 - 0s - loss: 0.0749 - 35ms/epoch - 9ms/step
# Epoch 693/1000
# 4/4 - 0s - loss: 0.0751 - 65ms/epoch - 16ms/step
# Epoch 694/1000
# 4/4 - 0s - loss: 0.0749 - 14ms/epoch - 3ms/step
# Epoch 695/1000
# 4/4 - 0s - loss: 0.0749 - 16ms/epoch - 4ms/step
# Epoch 696/1000
# 4/4 - 0s - loss: 0.0750 - 18ms/epoch - 5ms/step
# Epoch 697/1000
# 4/4 - 0s - loss: 0.0748 - 16ms/epoch - 4ms/step
# Epoch 698/1000
# 4/4 - 0s - loss: 0.0748 - 23ms/epoch - 6ms/step
# Epoch 699/1000
# 4/4 - 0s - loss: 0.0748 - 16ms/epoch - 4ms/step
# Epoch 700/1000
# 4/4 - 0s - loss: 0.0748 - 18ms/epoch - 4ms/step
# Epoch 701/1000
# 4/4 - 0s - loss: 0.0746 - 17ms/epoch - 4ms/step
# Epoch 702/1000
# 4/4 - 0s - loss: 0.0748 - 15ms/epoch - 4ms/step
# Epoch 703/1000
# 4/4 - 0s - loss: 0.0752 - 13ms/epoch - 3ms/step
# Epoch 704/1000
# 4/4 - 0s - loss: 0.0762 - 12ms/epoch - 3ms/step
# Epoch 705/1000
# 4/4 - 0s - loss: 0.0765 - 9ms/epoch - 2ms/step
# Epoch 706/1000
# 4/4 - 0s - loss: 0.0756 - 9ms/epoch - 2ms/step
# Epoch 707/1000
# 4/4 - 0s - loss: 0.0749 - 9ms/epoch - 2ms/step
# Epoch 708/1000
# 4/4 - 0s - loss: 0.0753 - 10ms/epoch - 3ms/step
# Epoch 709/1000
# 4/4 - 0s - loss: 0.0751 - 10ms/epoch - 2ms/step
# Epoch 710/1000
# 4/4 - 0s - loss: 0.0748 - 10ms/epoch - 3ms/step
# Epoch 711/1000
# 4/4 - 0s - loss: 0.0752 - 10ms/epoch - 2ms/step
# Epoch 712/1000
# 4/4 - 0s - loss: 0.0764 - 10ms/epoch - 2ms/step
# Epoch 713/1000
# 4/4 - 0s - loss: 0.0767 - 10ms/epoch - 2ms/step
# Epoch 714/1000
# 4/4 - 0s - loss: 0.0759 - 10ms/epoch - 3ms/step
# Epoch 715/1000
# 4/4 - 0s - loss: 0.0754 - 9ms/epoch - 2ms/step
# Epoch 716/1000
# 4/4 - 0s - loss: 0.0747 - 9ms/epoch - 2ms/step
# Epoch 717/1000
# 4/4 - 0s - loss: 0.0748 - 10ms/epoch - 2ms/step
# Epoch 718/1000
# 4/4 - 0s - loss: 0.0751 - 12ms/epoch - 3ms/step
# Epoch 719/1000
# 4/4 - 0s - loss: 0.0747 - 12ms/epoch - 3ms/step
# Epoch 720/1000
# 4/4 - 0s - loss: 0.0743 - 11ms/epoch - 3ms/step
# Epoch 721/1000
# 4/4 - 0s - loss: 0.0744 - 11ms/epoch - 3ms/step
# Epoch 722/1000
# 4/4 - 0s - loss: 0.0744 - 11ms/epoch - 3ms/step
# Epoch 723/1000
# 4/4 - 0s - loss: 0.0744 - 12ms/epoch - 3ms/step
# Epoch 724/1000
# 4/4 - 0s - loss: 0.0746 - 11ms/epoch - 3ms/step
# Epoch 725/1000
# 4/4 - 0s - loss: 0.0743 - 11ms/epoch - 3ms/step
# Epoch 726/1000
# 4/4 - 0s - loss: 0.0744 - 11ms/epoch - 3ms/step
# Epoch 727/1000
# 4/4 - 0s - loss: 0.0743 - 10ms/epoch - 2ms/step
# Epoch 728/1000
# 4/4 - 0s - loss: 0.0743 - 13ms/epoch - 3ms/step
# Epoch 729/1000
# 4/4 - 0s - loss: 0.0746 - 11ms/epoch - 3ms/step
# Epoch 730/1000
# 4/4 - 0s - loss: 0.0744 - 11ms/epoch - 3ms/step
# Epoch 731/1000
# 4/4 - 0s - loss: 0.0744 - 11ms/epoch - 3ms/step
# Epoch 732/1000
# 4/4 - 0s - loss: 0.0745 - 11ms/epoch - 3ms/step
# Epoch 733/1000
# 4/4 - 0s - loss: 0.0746 - 9ms/epoch - 2ms/step
# Epoch 734/1000
# 4/4 - 0s - loss: 0.0746 - 9ms/epoch - 2ms/step
# Epoch 735/1000
# 4/4 - 0s - loss: 0.0743 - 11ms/epoch - 3ms/step
# Epoch 736/1000
# 4/4 - 0s - loss: 0.0741 - 10ms/epoch - 2ms/step
# Epoch 737/1000
# 4/4 - 0s - loss: 0.0746 - 9ms/epoch - 2ms/step
# Epoch 738/1000
# 4/4 - 0s - loss: 0.0747 - 10ms/epoch - 2ms/step
# Epoch 739/1000
# 4/4 - 0s - loss: 0.0747 - 10ms/epoch - 2ms/step
# Epoch 740/1000
# 4/4 - 0s - loss: 0.0746 - 11ms/epoch - 3ms/step
# Epoch 741/1000
# 4/4 - 0s - loss: 0.0744 - 9ms/epoch - 2ms/step
# Epoch 742/1000
# 4/4 - 0s - loss: 0.0743 - 9ms/epoch - 2ms/step
# Epoch 743/1000
# 4/4 - 0s - loss: 0.0744 - 12ms/epoch - 3ms/step
# Epoch 744/1000
# 4/4 - 0s - loss: 0.0743 - 11ms/epoch - 3ms/step
# Epoch 745/1000
# 4/4 - 0s - loss: 0.0742 - 14ms/epoch - 3ms/step
# Epoch 746/1000
# 4/4 - 0s - loss: 0.0742 - 13ms/epoch - 3ms/step
# Epoch 747/1000
# 4/4 - 0s - loss: 0.0743 - 15ms/epoch - 4ms/step
# Epoch 748/1000
# 4/4 - 0s - loss: 0.0742 - 17ms/epoch - 4ms/step
# Epoch 749/1000
# 4/4 - 0s - loss: 0.0740 - 14ms/epoch - 3ms/step
# Epoch 750/1000
# 4/4 - 0s - loss: 0.0740 - 15ms/epoch - 4ms/step
# Epoch 751/1000
# 4/4 - 0s - loss: 0.0739 - 14ms/epoch - 3ms/step
# Epoch 752/1000
# 4/4 - 0s - loss: 0.0740 - 16ms/epoch - 4ms/step
# Epoch 753/1000
# 4/4 - 0s - loss: 0.0740 - 10ms/epoch - 2ms/step
# Epoch 754/1000
# 4/4 - 0s - loss: 0.0742 - 11ms/epoch - 3ms/step
# Epoch 755/1000
# 4/4 - 0s - loss: 0.0743 - 11ms/epoch - 3ms/step
# Epoch 756/1000
# 4/4 - 0s - loss: 0.0743 - 13ms/epoch - 3ms/step
# Epoch 757/1000
# 4/4 - 0s - loss: 0.0737 - 12ms/epoch - 3ms/step
# Epoch 758/1000
# 4/4 - 0s - loss: 0.0756 - 11ms/epoch - 3ms/step
# Epoch 759/1000
# 4/4 - 0s - loss: 0.0754 - 11ms/epoch - 3ms/step
# Epoch 760/1000
# 4/4 - 0s - loss: 0.0747 - 11ms/epoch - 3ms/step
# Epoch 761/1000
# 4/4 - 0s - loss: 0.0738 - 11ms/epoch - 3ms/step
# Epoch 762/1000
# 4/4 - 0s - loss: 0.0742 - 13ms/epoch - 3ms/step
# Epoch 763/1000
# 4/4 - 0s - loss: 0.0749 - 12ms/epoch - 3ms/step
# Epoch 764/1000
# 4/4 - 0s - loss: 0.0747 - 15ms/epoch - 4ms/step
# Epoch 765/1000
# 4/4 - 0s - loss: 0.0744 - 13ms/epoch - 3ms/step
# Epoch 766/1000
# 4/4 - 0s - loss: 0.0740 - 14ms/epoch - 3ms/step
# Epoch 767/1000
# 4/4 - 0s - loss: 0.0739 - 13ms/epoch - 3ms/step
# Epoch 768/1000
# 4/4 - 0s - loss: 0.0736 - 10ms/epoch - 2ms/step
# Epoch 769/1000
# 4/4 - 0s - loss: 0.0741 - 11ms/epoch - 3ms/step
# Epoch 770/1000
# 4/4 - 0s - loss: 0.0743 - 10ms/epoch - 3ms/step
# Epoch 771/1000
# 4/4 - 0s - loss: 0.0741 - 9ms/epoch - 2ms/step
# Epoch 772/1000
# 4/4 - 0s - loss: 0.0738 - 10ms/epoch - 2ms/step
# Epoch 773/1000
# 4/4 - 0s - loss: 0.0736 - 10ms/epoch - 3ms/step
# Epoch 774/1000
# 4/4 - 0s - loss: 0.0736 - 9ms/epoch - 2ms/step
# Epoch 775/1000
# 4/4 - 0s - loss: 0.0741 - 10ms/epoch - 2ms/step
# Epoch 776/1000
# 4/4 - 0s - loss: 0.0741 - 10ms/epoch - 2ms/step
# Epoch 777/1000
# 4/4 - 0s - loss: 0.0737 - 11ms/epoch - 3ms/step
# Epoch 778/1000
# 4/4 - 0s - loss: 0.0735 - 10ms/epoch - 2ms/step
# Epoch 779/1000
# 4/4 - 0s - loss: 0.0739 - 11ms/epoch - 3ms/step
# Epoch 780/1000
# 4/4 - 0s - loss: 0.0741 - 10ms/epoch - 2ms/step
# Epoch 781/1000
# 4/4 - 0s - loss: 0.0740 - 10ms/epoch - 2ms/step
# Epoch 782/1000
# 4/4 - 0s - loss: 0.0740 - 9ms/epoch - 2ms/step
# Epoch 783/1000
# 4/4 - 0s - loss: 0.0738 - 10ms/epoch - 2ms/step
# Epoch 784/1000
# 4/4 - 0s - loss: 0.0737 - 10ms/epoch - 2ms/step
# Epoch 785/1000
# 4/4 - 0s - loss: 0.0736 - 10ms/epoch - 2ms/step
# Epoch 786/1000
# 4/4 - 0s - loss: 0.0738 - 9ms/epoch - 2ms/step
# Epoch 787/1000
# 4/4 - 0s - loss: 0.0736 - 9ms/epoch - 2ms/step
# Epoch 788/1000
# 4/4 - 0s - loss: 0.0735 - 9ms/epoch - 2ms/step
# Epoch 789/1000
# 4/4 - 0s - loss: 0.0734 - 9ms/epoch - 2ms/step
# Epoch 790/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 791/1000
# 4/4 - 0s - loss: 0.0734 - 13ms/epoch - 3ms/step
# Epoch 792/1000
# 4/4 - 0s - loss: 0.0738 - 9ms/epoch - 2ms/step
# Epoch 793/1000
# 4/4 - 0s - loss: 0.0737 - 10ms/epoch - 2ms/step
# Epoch 794/1000
# 4/4 - 0s - loss: 0.0735 - 10ms/epoch - 2ms/step
# Epoch 795/1000
# 4/4 - 0s - loss: 0.0735 - 11ms/epoch - 3ms/step
# Epoch 796/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 797/1000
# 4/4 - 0s - loss: 0.0732 - 10ms/epoch - 2ms/step
# Epoch 798/1000
# 4/4 - 0s - loss: 0.0737 - 13ms/epoch - 3ms/step
# Epoch 799/1000
# 4/4 - 0s - loss: 0.0737 - 9ms/epoch - 2ms/step
# Epoch 800/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 801/1000
# 4/4 - 0s - loss: 0.0735 - 9ms/epoch - 2ms/step
# Epoch 802/1000
# 4/4 - 0s - loss: 0.0736 - 10ms/epoch - 2ms/step
# Epoch 803/1000
# 4/4 - 0s - loss: 0.0735 - 10ms/epoch - 2ms/step
# Epoch 804/1000
# 4/4 - 0s - loss: 0.0735 - 10ms/epoch - 3ms/step
# Epoch 805/1000
# 4/4 - 0s - loss: 0.0734 - 9ms/epoch - 2ms/step
# Epoch 806/1000
# 4/4 - 0s - loss: 0.0733 - 9ms/epoch - 2ms/step
# Epoch 807/1000
# 4/4 - 0s - loss: 0.0735 - 10ms/epoch - 2ms/step
# Epoch 808/1000
# 4/4 - 0s - loss: 0.0736 - 10ms/epoch - 2ms/step
# Epoch 809/1000
# 4/4 - 0s - loss: 0.0734 - 9ms/epoch - 2ms/step
# Epoch 810/1000
# 4/4 - 0s - loss: 0.0731 - 9ms/epoch - 2ms/step
# Epoch 811/1000
# 4/4 - 0s - loss: 0.0736 - 12ms/epoch - 3ms/step
# Epoch 812/1000
# 4/4 - 0s - loss: 0.0751 - 10ms/epoch - 3ms/step
# Epoch 813/1000
# 4/4 - 0s - loss: 0.0745 - 9ms/epoch - 2ms/step
# Epoch 814/1000
# 4/4 - 0s - loss: 0.0734 - 9ms/epoch - 2ms/step
# Epoch 815/1000
# 4/4 - 0s - loss: 0.0733 - 10ms/epoch - 2ms/step
# Epoch 816/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 817/1000
# 4/4 - 0s - loss: 0.0733 - 10ms/epoch - 2ms/step
# Epoch 818/1000
# 4/4 - 0s - loss: 0.0732 - 10ms/epoch - 2ms/step
# Epoch 819/1000
# 4/4 - 0s - loss: 0.0732 - 9ms/epoch - 2ms/step
# Epoch 820/1000
# 4/4 - 0s - loss: 0.0736 - 10ms/epoch - 2ms/step
# Epoch 821/1000
# 4/4 - 0s - loss: 0.0738 - 10ms/epoch - 2ms/step
# Epoch 822/1000
# 4/4 - 0s - loss: 0.0735 - 9ms/epoch - 2ms/step
# Epoch 823/1000
# 4/4 - 0s - loss: 0.0735 - 9ms/epoch - 2ms/step
# Epoch 824/1000
# 4/4 - 0s - loss: 0.0737 - 10ms/epoch - 3ms/step
# Epoch 825/1000
# 4/4 - 0s - loss: 0.0749 - 9ms/epoch - 2ms/step
# Epoch 826/1000
# 4/4 - 0s - loss: 0.0751 - 10ms/epoch - 2ms/step
# Epoch 827/1000
# 4/4 - 0s - loss: 0.0741 - 10ms/epoch - 2ms/step
# Epoch 828/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 3ms/step
# Epoch 829/1000
# 4/4 - 0s - loss: 0.0731 - 10ms/epoch - 2ms/step
# Epoch 830/1000
# 4/4 - 0s - loss: 0.0733 - 9ms/epoch - 2ms/step
# Epoch 831/1000
# 4/4 - 0s - loss: 0.0735 - 11ms/epoch - 3ms/step
# Epoch 832/1000
# 4/4 - 0s - loss: 0.0738 - 9ms/epoch - 2ms/step
# Epoch 833/1000
# 4/4 - 0s - loss: 0.0737 - 9ms/epoch - 2ms/step
# Epoch 834/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 835/1000
# 4/4 - 0s - loss: 0.0731 - 10ms/epoch - 2ms/step
# Epoch 836/1000
# 4/4 - 0s - loss: 0.0730 - 10ms/epoch - 3ms/step
# Epoch 837/1000
# 4/4 - 0s - loss: 0.0730 - 9ms/epoch - 2ms/step
# Epoch 838/1000
# 4/4 - 0s - loss: 0.0731 - 9ms/epoch - 2ms/step
# Epoch 839/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 2ms/step
# Epoch 840/1000
# 4/4 - 0s - loss: 0.0730 - 10ms/epoch - 2ms/step
# Epoch 841/1000
# 4/4 - 0s - loss: 0.0732 - 9ms/epoch - 2ms/step
# Epoch 842/1000
# 4/4 - 0s - loss: 0.0729 - 9ms/epoch - 2ms/step
# Epoch 843/1000
# 4/4 - 0s - loss: 0.0733 - 9ms/epoch - 2ms/step
# Epoch 844/1000
# 4/4 - 0s - loss: 0.0735 - 9ms/epoch - 2ms/step
# Epoch 845/1000
# 4/4 - 0s - loss: 0.0733 - 11ms/epoch - 3ms/step
# Epoch 846/1000
# 4/4 - 0s - loss: 0.0731 - 10ms/epoch - 2ms/step
# Epoch 847/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 2ms/step
# Epoch 848/1000
# 4/4 - 0s - loss: 0.0730 - 11ms/epoch - 3ms/step
# Epoch 849/1000
# 4/4 - 0s - loss: 0.0733 - 10ms/epoch - 2ms/step
# Epoch 850/1000
# 4/4 - 0s - loss: 0.0741 - 10ms/epoch - 2ms/step
# Epoch 851/1000
# 4/4 - 0s - loss: 0.0742 - 10ms/epoch - 2ms/step
# Epoch 852/1000
# 4/4 - 0s - loss: 0.0739 - 10ms/epoch - 2ms/step
# Epoch 853/1000
# 4/4 - 0s - loss: 0.0730 - 9ms/epoch - 2ms/step
# Epoch 854/1000
# 4/4 - 0s - loss: 0.0728 - 9ms/epoch - 2ms/step
# Epoch 855/1000
# 4/4 - 0s - loss: 0.0729 - 14ms/epoch - 4ms/step
# Epoch 856/1000
# 4/4 - 0s - loss: 0.0727 - 12ms/epoch - 3ms/step
# Epoch 857/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 3ms/step
# Epoch 858/1000
# 4/4 - 0s - loss: 0.0730 - 10ms/epoch - 2ms/step
# Epoch 859/1000
# 4/4 - 0s - loss: 0.0726 - 11ms/epoch - 3ms/step
# Epoch 860/1000
# 4/4 - 0s - loss: 0.0730 - 9ms/epoch - 2ms/step
# Epoch 861/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 2ms/step
# Epoch 862/1000
# 4/4 - 0s - loss: 0.0728 - 10ms/epoch - 3ms/step
# Epoch 863/1000
# 4/4 - 0s - loss: 0.0730 - 10ms/epoch - 2ms/step
# Epoch 864/1000
# 4/4 - 0s - loss: 0.0731 - 9ms/epoch - 2ms/step
# Epoch 865/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 2ms/step
# Epoch 866/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 3ms/step
# Epoch 867/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 868/1000
# 4/4 - 0s - loss: 0.0726 - 11ms/epoch - 3ms/step
# Epoch 869/1000
# 4/4 - 0s - loss: 0.0728 - 10ms/epoch - 3ms/step
# Epoch 870/1000
# 4/4 - 0s - loss: 0.0727 - 9ms/epoch - 2ms/step
# Epoch 871/1000
# 4/4 - 0s - loss: 0.0731 - 9ms/epoch - 2ms/step
# Epoch 872/1000
# 4/4 - 0s - loss: 0.0727 - 10ms/epoch - 2ms/step
# Epoch 873/1000
# 4/4 - 0s - loss: 0.0729 - 9ms/epoch - 2ms/step
# Epoch 874/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 875/1000
# 4/4 - 0s - loss: 0.0731 - 10ms/epoch - 3ms/step
# Epoch 876/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 3ms/step
# Epoch 877/1000
# 4/4 - 0s - loss: 0.0728 - 10ms/epoch - 2ms/step
# Epoch 878/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 2ms/step
# Epoch 879/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 3ms/step
# Epoch 880/1000
# 4/4 - 0s - loss: 0.0725 - 9ms/epoch - 2ms/step
# Epoch 881/1000
# 4/4 - 0s - loss: 0.0734 - 9ms/epoch - 2ms/step
# Epoch 882/1000
# 4/4 - 0s - loss: 0.0738 - 10ms/epoch - 2ms/step
# Epoch 883/1000
# 4/4 - 0s - loss: 0.0730 - 10ms/epoch - 3ms/step
# Epoch 884/1000
# 4/4 - 0s - loss: 0.0731 - 10ms/epoch - 2ms/step
# Epoch 885/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 2ms/step
# Epoch 886/1000
# 4/4 - 0s - loss: 0.0725 - 9ms/epoch - 2ms/step
# Epoch 887/1000
# 4/4 - 0s - loss: 0.0728 - 9ms/epoch - 2ms/step
# Epoch 888/1000
# 4/4 - 0s - loss: 0.0727 - 10ms/epoch - 2ms/step
# Epoch 889/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 3ms/step
# Epoch 890/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 3ms/step
# Epoch 891/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 892/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 893/1000
# 4/4 - 0s - loss: 0.0726 - 18ms/epoch - 4ms/step
# Epoch 894/1000
# 4/4 - 0s - loss: 0.0726 - 15ms/epoch - 4ms/step
# Epoch 895/1000
# 4/4 - 0s - loss: 0.0726 - 12ms/epoch - 3ms/step
# Epoch 896/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 2ms/step
# Epoch 897/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 898/1000
# 4/4 - 0s - loss: 0.0728 - 9ms/epoch - 2ms/step
# Epoch 899/1000
# 4/4 - 0s - loss: 0.0726 - 9ms/epoch - 2ms/step
# Epoch 900/1000
# 4/4 - 0s - loss: 0.0723 - 10ms/epoch - 2ms/step
# Epoch 901/1000
# 4/4 - 0s - loss: 0.0728 - 10ms/epoch - 3ms/step
# Epoch 902/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 2ms/step
# Epoch 903/1000
# 4/4 - 0s - loss: 0.0727 - 10ms/epoch - 2ms/step
# Epoch 904/1000
# 4/4 - 0s - loss: 0.0728 - 10ms/epoch - 2ms/step
# Epoch 905/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 2ms/step
# Epoch 906/1000
# 4/4 - 0s - loss: 0.0725 - 9ms/epoch - 2ms/step
# Epoch 907/1000
# 4/4 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 908/1000
# 4/4 - 0s - loss: 0.0729 - 12ms/epoch - 3ms/step
# Epoch 909/1000
# 4/4 - 0s - loss: 0.0725 - 11ms/epoch - 3ms/step
# Epoch 910/1000
# 4/4 - 0s - loss: 0.0724 - 9ms/epoch - 2ms/step
# Epoch 911/1000
# 4/4 - 0s - loss: 0.0724 - 9ms/epoch - 2ms/step
# Epoch 912/1000
# 4/4 - 0s - loss: 0.0726 - 9ms/epoch - 2ms/step
# Epoch 913/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 914/1000
# 4/4 - 0s - loss: 0.0724 - 10ms/epoch - 2ms/step
# Epoch 915/1000
# 4/4 - 0s - loss: 0.0724 - 11ms/epoch - 3ms/step
# Epoch 916/1000
# 4/4 - 0s - loss: 0.0725 - 11ms/epoch - 3ms/step
# Epoch 917/1000
# 4/4 - 0s - loss: 0.0722 - 9ms/epoch - 2ms/step
# Epoch 918/1000
# 4/4 - 0s - loss: 0.0721 - 9ms/epoch - 2ms/step
# Epoch 919/1000
# 4/4 - 0s - loss: 0.0721 - 10ms/epoch - 2ms/step
# Epoch 920/1000
# 4/4 - 0s - loss: 0.0722 - 9ms/epoch - 2ms/step
# Epoch 921/1000
# 4/4 - 0s - loss: 0.0722 - 10ms/epoch - 3ms/step
# Epoch 922/1000
# 4/4 - 0s - loss: 0.0722 - 10ms/epoch - 2ms/step
# Epoch 923/1000
# 4/4 - 0s - loss: 0.0722 - 9ms/epoch - 2ms/step
# Epoch 924/1000
# 4/4 - 0s - loss: 0.0717 - 10ms/epoch - 2ms/step
# Epoch 925/1000
# 4/4 - 0s - loss: 0.0722 - 10ms/epoch - 2ms/step
# Epoch 926/1000
# 4/4 - 0s - loss: 0.0729 - 10ms/epoch - 2ms/step
# Epoch 927/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 928/1000
# 4/4 - 0s - loss: 0.0722 - 11ms/epoch - 3ms/step
# Epoch 929/1000
# 4/4 - 0s - loss: 0.0722 - 10ms/epoch - 2ms/step
# Epoch 930/1000
# 4/4 - 0s - loss: 0.0724 - 9ms/epoch - 2ms/step
# Epoch 931/1000
# 4/4 - 0s - loss: 0.0720 - 10ms/epoch - 2ms/step
# Epoch 932/1000
# 4/4 - 0s - loss: 0.0725 - 11ms/epoch - 3ms/step
# Epoch 933/1000
# 4/4 - 0s - loss: 0.0726 - 11ms/epoch - 3ms/step
# Epoch 934/1000
# 4/4 - 0s - loss: 0.0726 - 10ms/epoch - 2ms/step
# Epoch 935/1000
# 4/4 - 0s - loss: 0.0723 - 10ms/epoch - 3ms/step
# Epoch 936/1000
# 4/4 - 0s - loss: 0.0724 - 10ms/epoch - 3ms/step
# Epoch 937/1000
# 4/4 - 0s - loss: 0.0724 - 10ms/epoch - 2ms/step
# Epoch 938/1000
# 4/4 - 0s - loss: 0.0722 - 9ms/epoch - 2ms/step
# Epoch 939/1000
# 4/4 - 0s - loss: 0.0726 - 9ms/epoch - 2ms/step
# Epoch 940/1000
# 4/4 - 0s - loss: 0.0722 - 9ms/epoch - 2ms/step
# Epoch 941/1000
# 4/4 - 0s - loss: 0.0721 - 10ms/epoch - 3ms/step
# Epoch 942/1000
# 4/4 - 0s - loss: 0.0721 - 9ms/epoch - 2ms/step
# Epoch 943/1000
# 4/4 - 0s - loss: 0.0719 - 10ms/epoch - 2ms/step
# Epoch 944/1000
# 4/4 - 0s - loss: 0.0722 - 10ms/epoch - 2ms/step
# Epoch 945/1000
# 4/4 - 0s - loss: 0.0723 - 10ms/epoch - 2ms/step
# Epoch 946/1000
# 4/4 - 0s - loss: 0.0722 - 10ms/epoch - 3ms/step
# Epoch 947/1000
# 4/4 - 0s - loss: 0.0723 - 10ms/epoch - 2ms/step
# Epoch 948/1000
# 4/4 - 0s - loss: 0.0722 - 9ms/epoch - 2ms/step
# Epoch 949/1000
# 4/4 - 0s - loss: 0.0723 - 9ms/epoch - 2ms/step
# Epoch 950/1000
# 4/4 - 0s - loss: 0.0721 - 10ms/epoch - 2ms/step
# Epoch 951/1000
# 4/4 - 0s - loss: 0.0727 - 10ms/epoch - 2ms/step
# Epoch 952/1000
# 4/4 - 0s - loss: 0.0733 - 11ms/epoch - 3ms/step
# Epoch 953/1000
# 4/4 - 0s - loss: 0.0735 - 10ms/epoch - 3ms/step
# Epoch 954/1000
# 4/4 - 0s - loss: 0.0731 - 12ms/epoch - 3ms/step
# Epoch 955/1000
# 4/4 - 0s - loss: 0.0730 - 12ms/epoch - 3ms/step
# Epoch 956/1000
# 4/4 - 0s - loss: 0.0734 - 14ms/epoch - 4ms/step
# Epoch 957/1000
# 4/4 - 0s - loss: 0.0734 - 12ms/epoch - 3ms/step
# Epoch 958/1000
# 4/4 - 0s - loss: 0.0728 - 10ms/epoch - 3ms/step
# Epoch 959/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 960/1000
# 4/4 - 0s - loss: 0.0723 - 10ms/epoch - 2ms/step
# Epoch 961/1000
# 4/4 - 0s - loss: 0.0719 - 11ms/epoch - 3ms/step
# Epoch 962/1000
# 4/4 - 0s - loss: 0.0719 - 12ms/epoch - 3ms/step
# Epoch 963/1000
# 4/4 - 0s - loss: 0.0721 - 13ms/epoch - 3ms/step
# Epoch 964/1000
# 4/4 - 0s - loss: 0.0723 - 12ms/epoch - 3ms/step
# Epoch 965/1000
# 4/4 - 0s - loss: 0.0721 - 12ms/epoch - 3ms/step
# Epoch 966/1000
# 4/4 - 0s - loss: 0.0718 - 11ms/epoch - 3ms/step
# Epoch 967/1000
# 4/4 - 0s - loss: 0.0717 - 12ms/epoch - 3ms/step
# Epoch 968/1000
# 4/4 - 0s - loss: 0.0717 - 10ms/epoch - 2ms/step
# Epoch 969/1000
# 4/4 - 0s - loss: 0.0718 - 13ms/epoch - 3ms/step
# Epoch 970/1000
# 4/4 - 0s - loss: 0.0721 - 11ms/epoch - 3ms/step
# Epoch 971/1000
# 4/4 - 0s - loss: 0.0715 - 10ms/epoch - 3ms/step
# Epoch 972/1000
# 4/4 - 0s - loss: 0.0715 - 15ms/epoch - 4ms/step
# Epoch 973/1000
# 4/4 - 0s - loss: 0.0715 - 11ms/epoch - 3ms/step
# Epoch 974/1000
# 4/4 - 0s - loss: 0.0714 - 9ms/epoch - 2ms/step
# Epoch 975/1000
# 4/4 - 0s - loss: 0.0719 - 9ms/epoch - 2ms/step
# Epoch 976/1000
# 4/4 - 0s - loss: 0.0724 - 10ms/epoch - 3ms/step
# Epoch 977/1000
# 4/4 - 0s - loss: 0.0720 - 10ms/epoch - 2ms/step
# Epoch 978/1000
# 4/4 - 0s - loss: 0.0715 - 9ms/epoch - 2ms/step
# Epoch 979/1000
# 4/4 - 0s - loss: 0.0716 - 9ms/epoch - 2ms/step
# Epoch 980/1000
# 4/4 - 0s - loss: 0.0720 - 10ms/epoch - 2ms/step
# Epoch 981/1000
# 4/4 - 0s - loss: 0.0719 - 10ms/epoch - 3ms/step
# Epoch 982/1000
# 4/4 - 0s - loss: 0.0717 - 9ms/epoch - 2ms/step
# Epoch 983/1000
# 4/4 - 0s - loss: 0.0715 - 10ms/epoch - 2ms/step
# Epoch 984/1000
# 4/4 - 0s - loss: 0.0715 - 10ms/epoch - 2ms/step
# Epoch 985/1000
# 4/4 - 0s - loss: 0.0715 - 11ms/epoch - 3ms/step
# Epoch 986/1000
# 4/4 - 0s - loss: 0.0715 - 10ms/epoch - 2ms/step
# Epoch 987/1000
# 4/4 - 0s - loss: 0.0715 - 10ms/epoch - 2ms/step
# Epoch 988/1000
# 4/4 - 0s - loss: 0.0713 - 10ms/epoch - 2ms/step
# Epoch 989/1000
# 4/4 - 0s - loss: 0.0712 - 9ms/epoch - 2ms/step
# Epoch 990/1000
# 4/4 - 0s - loss: 0.0717 - 9ms/epoch - 2ms/step
# Epoch 991/1000
# 4/4 - 0s - loss: 0.0723 - 9ms/epoch - 2ms/step
# Epoch 992/1000
# 4/4 - 0s - loss: 0.0725 - 9ms/epoch - 2ms/step
# Epoch 993/1000
# 4/4 - 0s - loss: 0.0719 - 10ms/epoch - 2ms/step
# Epoch 994/1000
# 4/4 - 0s - loss: 0.0719 - 11ms/epoch - 3ms/step
# Epoch 995/1000
# 4/4 - 0s - loss: 0.0725 - 10ms/epoch - 2ms/step
# Epoch 996/1000
# 4/4 - 0s - loss: 0.0723 - 10ms/epoch - 2ms/step
# Epoch 997/1000
# 4/4 - 0s - loss: 0.0718 - 9ms/epoch - 2ms/step
# Epoch 998/1000
# 4/4 - 0s - loss: 0.0713 - 10ms/epoch - 2ms/step
# Epoch 999/1000
# 4/4 - 0s - loss: 0.0713 - 10ms/epoch - 2ms/step
# Epoch 1000/1000
# 4/4 - 0s - loss: 0.0721 - 9ms/epoch - 2ms/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A5B0244B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Mean Squared Error: 0.0722

# %%
# Test the model
test_data = np.random.rand(10,5)
test_labels = np.random.randint(0, 2, size=(10, 1))
score = model.evaluate(test_data, test_labels)
#print('Test loss:', loss)
#print(f'Test accuracy: {score[1]}')
# Out:
# 1/1 [==============================] - 0s 149ms/step - loss: 0.3209

# %%
from keras.layers import Input, Dense
from keras.models import Model

X_train = np.random.rand(100,5)

# generate random output data
y_train = np.random.rand(100, 1)


# generate random input data
X_val = np.random.rand(100,5)

# generate random output data
y_val = np.random.rand(100, 1)


input_layer = Input(shape=(5,)) #number of node == 1st element of shape== colloumn
hidden_layer = Dense(50, activation='relu')(input_layer)
hidden_layer = Dense(50, activation='relu')(hidden_layer)
output_layer = Dense(1, activation='sigmoid')(hidden_layer)
model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 132ms/step - loss: 0.6966 - accuracy: 0.0000e+00 - val_loss: 0.6942 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6929 - accuracy: 0.0000e+00 - val_loss: 0.6934 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6896 - accuracy: 0.0000e+00 - val_loss: 0.6935 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6879 - accuracy: 0.0000e+00 - val_loss: 0.6940 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6863 - accuracy: 0.0000e+00 - val_loss: 0.6940 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6855 - accuracy: 0.0000e+00 - val_loss: 0.6937 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6847 - accuracy: 0.0000e+00 - val_loss: 0.6936 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6840 - accuracy: 0.0000e+00 - val_loss: 0.6934 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6835 - accuracy: 0.0000e+00 - val_loss: 0.6932 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6835 - accuracy: 0.0000e+00 - val_loss: 0.6930 - val_accuracy: 0.0000e+00

# %%
# Test the model
test_data = np.random.rand(10,5)
test_labels = np.random.randint(0, 2, size=(10, 1))
score = model.evaluate(test_data, test_labels)
# Out:
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6901 - accuracy: 0.6000

# %% [markdown]
# A dense layer with 10
# units means that the layer has 32 neurons, also known as nodes or units. Each of these neurons is fully connected to the neurons in the previous layer (or input data, if this is the first layer), and the output of each neuron is calculated as a weighted sum of the inputs, followed by an activation function.

# %% [markdown]
# ### Convolutional layer

# %% [markdown]
# The convolution operation involves sliding a small filter, also known as a kernel or weight matrix, over the input image and computing a dot product between the filter and the corresponding patch of pixels. The result is a new matrix, called a feature map, that highlights the presence of certain patterns or structures in the input image.

# %% [markdown]
# Convolutional layers are often followed by pooling layers, which downsample the feature maps by either taking the maximum or average value over a local region. This reduces the size of the feature maps while retaining the most important information.

# %% [markdown]
# #### OParations of CNN

# %% [markdown]
# Convolutional Layer: The input data, typically an image, is fed into the first convolutional layer. The convolutional layer applies a set of learnable filters (also called kernels) to the input data, performing a convolution operation. The output of the convolutional layer is a set of feature maps that capture different aspects of the input data.

# %% [markdown]
# Activation Function: Each element of the feature maps is then passed through a non-linear activation function, such as ReLU, to introduce non-linearity into the network.

# %% [markdown]
# Pooling Layer: The output of the activation function is then typically passed through a pooling layer, which reduces the spatial dimensions of the feature maps while retaining the most important information. Common pooling operations include max pooling and average pooling.

# %% [markdown]
# In a CNN built using Keras, a pooling layer can be added to the model using the MaxPooling2D or AveragePooling2D layer classes.

# %% [markdown]
# The pool_size argument specifies the size of the pooling window as a tuple of two integers. In this case, the window is 2x2, meaning that the pooling operation is performed over non-overlapping 2x2 regions of the feature map. The MaxPooling2D layer computes the maximum value within each pooling window and passes it to the next layer in the model.

# %% [markdown]
# The pooling kernel/filter is a small matrix that is used to downsample the feature map produced by the previous convolutional layer. The filter is applied to the feature map in a sliding window manner, where the filter is moved across the input with a specific stride and a pooling operation is applied at each window location.

# %% [markdown]
# Downsampling can also refer to other techniques used to reduce the size of data, such as subsampling, decimation, or compression. In the context of CNNs, however, downsampling usually refers specifically to the process of reducing the spatial dimensionality of the feature maps.

# %% [markdown]
#  downsampling is an important technique in CNNs for reducing the computational cost and memory requirements of the model, while preserving the most important features in the data.

# %% [markdown]
# a color image with dimensions 224x224 pixels and 3 color channels (red, green, and blue) would be represented as a 3-dimensional array with shape (224, 224, 3). The first two dimensions represent the height and width of the image, and the third dimension represents the color channels.

# %% [markdown]
# #####  learnable filters

# %% [markdown]
# A filter is a small matrix of numbers that is convolved with the input data to produce a feature map. For example, a 3x3 filter can be used to extract edges or corners from an image, while a larger 5x5 filter can capture more complex features such as textures or shapes.

# %%
from keras.models import Sequential
from keras.layers import InputLayer, Conv2D , MaxPooling2D

# Define the input shape of the image
input_shape = (224, 224, 3)  # height, width, color channels

# Create a Sequential model
model = Sequential()

# Add an input layer to the model
model.add(InputLayer(input_shape=input_shape))

# Add a convolutional layer to the model with ReLU activation
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
# Example with sigmoid activation
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='sigmoid'))

# Example with tanh activation
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='tanh'))

# Example with softmax activation
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='softmax'))

# Add a max pooling layer to the model
model.add(MaxPooling2D(pool_size=(2, 2)))

# Print the model summary
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 222, 222, 16)      448
#
#  conv2d_8 (Conv2D)           (None, 220, 220, 16)      2320
#
#  conv2d_9 (Conv2D)           (None, 218, 218, 16)      2320
#
#  conv2d_10 (Conv2D)          (None, 216, 216, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 108, 108, 16)     0
#  )
#
# =================================================================
# Total params: 7,408
# Trainable params: 7,408
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Model description

# %% [markdown]
# #### Input Layers

# %% [markdown]
# filters=16: the number of filters to use in the layer. In this case, the layer will learn 16 filters, each of which will extract a different set of features from the input image.

# %% [markdown]
# kernel_size=(3, 3): the size of the filters, specified as a tuple of two integers. In this case, the filters will be 3x3 in size.

# %% [markdown]
# activation='relu': the activation function to use after applying the filters. In this case, the Rectified Linear Unit (ReLU) function will be used, which has been shown to be effective in deep learning models.

# %% [markdown]
# input_shape=input_shape: the shape of the input data, specified as a tuple of three integers. In this case, the input data is expected to have a height and width of 224 pixels, and 3 color channels (red, green, and blue).

# %% [markdown]
# Activation Function: Each element of the feature maps is then passed through a non-linear activation function, such as ReLU, to introduce non-linearity into the network.

# %% [markdown]
# Repeat Steps 1-3: The output of the pooling layer is then passed into another convolutional layer, followed by another activation function and pooling layer. This process is repeated for several layers, allowing the network to learn increasingly complex features.

# %% [markdown]
# Fully Connected Layer: Once the feature maps have been extracted, they are flattened and passed through one or more fully connected layers, which perform a traditional neural network operation. The output of the final fully connected layer is the network's prediction for the input data.

# %% [markdown]
# Loss Function: The output of the network is compared to the true label using a loss function, such as cross-entropy loss. The goal of training the network is to minimize this loss function by adjusting the learnable parameters in the network, such as the filter weights.

# %% [markdown]
# Optimization: The parameters of the network are updated using an optimization algorithm, such as stochastic gradient descent (SGD), to minimize the loss function. The process of updating the parameters is typically done using backpropagation, which computes the gradient of the loss with respect to each parameter in the network.

# %% [markdown]
# #### complete CNN project in python

# %% [markdown]
# Data preparation:
#
# Load and preprocess the image data using libraries such as NumPy, Pandas, and OpenCV.
#
# Split the data into training, validation, and testing sets.
#
# Apply data augmentation techniques to increase the size of the training dataset.

# %% [markdown]
# Model architecture definition:
#
# Define the architecture of the CNN using Keras or TensorFlow libraries.
#
# Add multiple convolutional and pooling layers to extract features from the input images.
#
# Flatten the output of the last convolutional layer to pass it to the fully connected layers.
#
# Add fully connected layers and an output layer with the appropriate number of neurons for the given task.
#
# Specify the loss function, optimizer, and evaluation metrics to use during training.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the architecture of the CNN
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
#32: The number of output filters in the convolution. This means that the layer will learn 32 different feature maps or filters.
#(3, 3): The size of the convolutional kernel or filter. In this case, the kernel size is 3x3.
#activation='relu': The activation function to apply to the output of the convolutional layer. In this case, Rectified Linear Unit (ReLU) activation function is used.
#input_shape=(64, 64, 3): The shape of the input data. This is a 3D tensor with a shape of (64, 64, 3), which corresponds to a 64x64 RGB image. The 3 in the end represents the number of color channels in the image, i.e., Red, Green and Blue.
"""(64, 64, 3) is a shape tuple used to represent the dimensions of a 
3-channel image or a 3-dimensional array with 64 rows, 64 columns, and 3 color channels (Red, Green, and Blue). 
The first two dimensions represent the height and width of the image or array, and the third dimension represents the number of channels. In this case, since there are 3 channels, the shape tuple has a length of 3."""

model.add(MaxPooling2D((2, 2)))
"""The MaxPooling2D layer can help to reduce the dimensionality of 
the feature maps and extract the most relevant information from the input images,"""
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Model training and evaluation:
#
# Train the model using the training dataset and the defined architecture.
#
# Monitor the training progress and tune the hyperparameters as necessary.
#
# Evaluate the model using the validation dataset and check for overfitting.
#
# Fine-tune the model based on the evaluation results.

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=64, epochs=10, validation_data=(X_test, y_test), verbose=1)

# %% [markdown]
# Prediction:
#
# Use the trained model to make predictions on new data.
#
# Preprocess the new data in the same way as the training data.
#
# Use the predict method in Keras or TensorFlow to get the predicted labels or probabilities for the new data.

# %%
# Evaluate the model on the test data
scores = model.evaluate(X_test, y_test, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))

# %% [markdown]
# Optimizers are algorithms used to update the parameters of a neural network during training in order to minimize the loss function. Keras provides several built-in optimizers that you can use to train your neural network models. Here are some of the commonly used optimizers in Keras:
#
# SGD (Stochastic Gradient Descent): This is a simple optimizer that updates the parameters in the direction of the negative gradient of the loss function. It is computationally efficient and easy to implement, but can be slow to converge and can get stuck in local minima.
#
# Adam (Adaptive Moment Estimation): This is an adaptive learning rate optimizer that combines the benefits of both Adagrad and RMSProp. It is computationally efficient, easy to implement, and works well in practice.
#
# RMSprop (Root Mean Square Propagation): This is an adaptive learning rate optimizer that divides the learning rate by a running average of the magnitudes of recent gradients. It helps to prevent the learning rate from decreasing too quickly and getting stuck in local minima.
#
# Adagrad (Adaptive Gradient Algorithm): This is an adaptive learning rate optimizer that updates the learning rate for each parameter based on the magnitude of the gradients. It works well for sparse data and can handle non-stationary objectives.
#
# Adadelta (Adaptive Delta): This is an extension of Adagrad that seeks to reduce its aggressive and monotonically decreasing learning rate. It uses a moving window of the root mean squared gradients to adaptively adjust the learning rate.

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, Dense

# Generate some random input data
input_data = np.random.rand(100, 10)

# Define the input layer
inputs = Input(shape=(10,))

# Define the first hidden layer
x = Dense(32, activation='relu')(inputs)

# Define the second hidden layer
x = Dense(16, activation='relu')(x)

# Define the output layer
outputs = Dense(1, activation='sigmoid')(x)

# Create the Keras model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
labels = np.random.randint(0, 2, size=(100, 1))
model.fit(input_data, labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 4s 36ms/step - loss: 0.6912 - accuracy: 0.5800
# Epoch 2/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5800
# Epoch 3/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6864 - accuracy: 0.6200
# Epoch 4/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6850 - accuracy: 0.6200
# Epoch 5/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6835 - accuracy: 0.6100
# Epoch 6/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6823 - accuracy: 0.6000
# Epoch 7/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6816 - accuracy: 0.6000
# Epoch 8/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6808 - accuracy: 0.6100
# Epoch 9/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.6000
# Epoch 10/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6793 - accuracy: 0.6000

# %%
# Test the model
test_data = np.random.rand(10, 10)
test_labels = np.random.randint(0, 2, size=(10, 1))
loss, accuracy = model.evaluate(test_data, test_labels)
print('Test loss:', loss)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.6329 - accuracy: 0.8000
# Test loss: 0.63291335105896

# %%
print(f'Test accuracy: {accuracy}')
# Out:
# Test accuracy: 0.800000011920929

# %% [markdown]
# There are several types of neural networks, including:
#
# Feedforward Neural Networks (FFNN): This is the most basic type of neural network, where data flows only in one direction, from input to output. These networks are used for tasks such as image classification, speech recognition, and language translation.
#
# Convolutional Neural Networks (CNN): These networks are commonly used for image recognition tasks. They use convolutional layers to extract features from images.
#
# Recurrent Neural Networks (RNN): These networks are used for tasks that involve sequential data, such as time-series analysis and language modeling. They use feedback loops to process and store information from previous time steps.
#
# Long Short-Term Memory (LSTM) Networks: These are a type of RNN that are specifically designed to handle long-term dependencies. They are commonly used in natural language processing and speech recognition.
#
# Autoencoders: These networks are used for unsupervised learning, where the goal is to learn a compressed representation of the input data. They are commonly used for tasks such as image compression and anomaly detection.
#
# Generative Adversarial Networks (GANs): These networks are used for generating new data that is similar to the training data. They consist of a generator network that generates the data, and a discriminator network that tries to distinguish between the generated data and the real data.
#
# Reinforcement Learning Networks: These networks are used for teaching agents how to make decisions in a dynamic environment. They receive rewards for making good decisions and punishments for making bad ones.
